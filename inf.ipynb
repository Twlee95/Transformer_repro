# %%
import torch
from model import Transformer
import config 
from load_data import prepare_data

# ckpt.pth 파일 경로
ckpt_path = "/home/user15/TT4/model/100000_checkpoint_h1.pth"

# 파일 불러오기
checkpoint = torch.load(ckpt_path, map_location=torch.device('cpu'))

# 내용 확인
for key in checkpoint.keys():
    print(f"{key}: {type(checkpoint[key])}")

model = Transformer(config.vocab_size, config.embedding_dimension,config.hidden_dimension,config.n_head,config.n_layers,config.h_ff, config.dropout_rate, config.device)
model.load_state_dict(checkpoint['model_state_dict'], strict=True)
model.to(config.device)

tokenizer = checkpoint['tokenizer']

# Data load
dev_pairs, tokenizer = prepare_data(config.path_ , tokenizer, 'test', config.max_sentence_len)
print("source data is loaded...")

print(len(dev_pairs[0]))

from tokenizers import Tokenizer
import math
#tokenizer = Tokenizer.from_file(config.token_path_)

output_file = "gen_sentences.txt"
ref_file = "ref_sentences.txt"

# 파일 초기화 (기존 파일 삭제 후 새로 생성)
with open(output_file, "w", encoding="utf-8") as f1, open(ref_file, "w", encoding="utf-8") as f2:

    model.eval()
    with torch.no_grad():
        for src, tgt in dev_pairs:
            input_src = torch.tensor(src, dtype=torch.long).to(config.device)
            output_tgt = torch.tensor(tgt, dtype=torch.long).to(config.device)

            #print(input_src.size())
            # Encoder 처리
            enc_attn_mask = model.gen_att_mask(input_src.unsqueeze(0), config.PAD)  # batch, seq
            # print("enc_attn_mask",enc_attn_mask.size())
            # print("enc_attn_mask",enc_attn_mask)
            embedded_src = model.embedding(input_src.unsqueeze(0)) * math.sqrt(config.embedding_dimension)
            pos_src = model.Positional_Embedding(embedded_src, config.device).unsqueeze(0)
            dr_src = model.dropout(pos_src + embedded_src)
            encoder_output = model.transformer_encoder(dr_src, enc_attn_mask)

            # print("encoder_output",encoder_output.size())
            # print("encoder_output",encoder_output)

            # Decoding 시작
            start_tk = torch.tensor([tokenizer.encode("<s>").ids[0]], dtype=torch.long).to(config.device)  # <s> token

            # print("start_tk",start_tk.unsqueeze(0))
            decoder_input = start_tk.unsqueeze(0)  # 첫 입력은 시작 토큰

            sequences = [[[start_tk.item()], 0.0, decoder_input]] # (sequence, score, decoder input)

            for _ in range(config.MAX_LEN):
                all_candidates = []

                for seq, score, decoder_input in sequences:
                    # 종료 토큰 <eos> 확인
                    if len(seq) > 0 and seq[-1] == tokenizer.encode("</s>").ids[0]:
                        all_candidates.append([seq, score, decoder_input])
                        continue

                    #print("decoder_input: ", decoder_input.size())
                    dec_attn_mask = model.gen_att_mask(decoder_input, config.PAD)
                    # 현재 입력 처리
                    embedded_st = model.embedding(decoder_input) * math.sqrt(config.embedding_dimension)
                    pos_st = model.Positional_Embedding(embedded_st, config.device)
                    dec_embed_input = model.dropout(pos_st + embedded_st)

                    # 디코더 실행
                    decoder_output = model.transformer_decoder(encoder_output, dec_embed_input, enc_attn_mask, dec_attn_mask)
                    
                    # print("decoder_output",decoder_output.size())
                    # print("decoder_output",decoder_output[:, -1, :].size())
                    #print("decoder_output",decoder_output[:, -1, :])

                    logits = model.fc_out(decoder_output[:, -1, :])  # 마지막 타임스텝의 출력
                    log_probs = torch.nn.functional.log_softmax(logits, dim=-1)

                    # Top-k 추출
                    topk_log_prob, topk_ids = torch.topk(log_probs, 4, dim=-1)

                    for j in range(4):  # beam size
                        word_idx = topk_ids[0, j].item()  # 새로 생성된 단어의 인덱스
                        prob = topk_log_prob[0, j].item()  # 해당 단어의 확률

                        # 새로운 시퀀스 업데이트
                        new_sequence = seq + [word_idx]  # 기존 시퀀스에 새로운 단어 추가

                        # 새로운 입력 생성 (현재 시퀀스에 따라 업데이트)
                        new_decoder_input = torch.tensor([new_sequence], dtype=torch.long, device=config.device)
                        #new_decoder_input = torch.tensor([[word_idx]], dtype=torch.long, device=config.device)
                        #print("new_decoder_input: ", new_decoder_input.size())

                        # 점수 업데이트
                        new_score = score + prob

                        # 새로운 후보 추가
                        all_candidates.append([new_sequence, new_score, new_decoder_input])

                # Top-k 유지
                #print("all_candidates",all_candidates)
                ordered = sorted(all_candidates, key=lambda x: x[1], reverse=True)
                sequences = ordered[:4]  # beam size 유지

                # 모든 시퀀스가 종료되었는지 확인
                if all(len(seq) > 0 and seq[-1] == tokenizer.encode("</s>").ids[0] for seq, _, _ in sequences):
                    break

            # 최종 시퀀스 선택
            
            best_sequence = sequences[0][0]

            #print("sequences",sequences)
            # 종료 토큰 제거
            if best_sequence[-1] == tokenizer.encode("</s>").ids[0]:
                best_sequence = best_sequence[1:-1]

            # print("best_sequence",best_sequence)
            
            # 디코딩
            
            target_sentence = tokenizer.decode(output_tgt.tolist())
            generated_sentence = tokenizer.decode(best_sequence)
            source_sentence = tokenizer.decode(input_src.tolist())

            # 결과 출력
            #print(f"input_src: {input_src.tolist()}")
            print(f"Source: {source_sentence}")

            #print(f"best_sequence: {best_sequence}")
            print(f"Generated: {generated_sentence}")

            #print("output_tgt",output_tgt.tolist())
            print(f"Target: {target_sentence}")
            print("@@@@@@@@@@@@@")

            # 파일 저장
            f1.write(generated_sentence + "\n")
            f2.write(target_sentence + "\n")
# Out:
# /tmp/ipykernel_40878/3619305990.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=torch.device('cpu'))
# step: <class 'int'>
# model_state_dict: <class 'collections.OrderedDict'>
# optimizer_state_dict: <class 'dict'>
# scheduler_state_dict: <class 'dict'>
# train_losses: <class 'list'>
# train_ppls: <class 'list'>
# tokenizer: <class 'tokenizers.Tokenizer'>
#
# Loading saved tokenizer...
# length of the pairs 2972
# source data is loaded...
# 2
# Source: A Republican strategy to counter the re - election of Obama
# Generated: Eine republikanische Strategie gegen die Wiederwahl von Obama
# Target: Eine republikanische Strategie , um der Wiederwahl von Obama entgegenzutreten
# @@@@@@@@@@@@@
# Source: Republican leaders justified their policy by the need to combat electoral fraud .
# Generated: Die republikanische Fuhrung rechtfertigte ihre Politik mit der Notwendigkeit , Wahlbetrug zu bekampfen .
# Target: Die Fuhrungskrafte der Republikaner rechtfertigen ihre Politik mit der Notwendigkeit , den Wahlbetrug zu bekampfen .
# @@@@@@@@@@@@@
# Source: However , the Brennan Centre considers this a myth , stating that electoral fraud is rarer in the United States than the number of people killed by lightning .
# Generated: Das Brennan - Zentrum halt dies jedoch fur einen Mythos , der besagt , dass Wahlbetrug in den Vereinigten Staaten seltener ist als die Anzahl der Menschen , die durch Blitze getotet werden .
# Target: Allerdings halt das Brennan Center letzteres fur einen Mythos , indem es bekraftigt , dass der Wahlbetrug in den USA seltener ist als die Anzahl der vom Blitzschlag getoteten Menschen .
# @@@@@@@@@@@@@
# Source: Indeed , Republican lawyers identified only 300 cases of electoral fraud in the United States in a decade .
# Generated: Tatsachlich identifizierten republikanische Anwalte in den Vereinigten Staaten innerhalb eines Jahrzehnts nur 300 Falle von Wahlbetrug .
# Target: Die Rechtsanwalte der Republikaner haben in 10 Jahren in den USA ubrigens nur 300 Falle von Wahlbetrug verzeichnet .
# @@@@@@@@@@@@@
# Source: One thing is certain : these new provisions will have a negative impact on voter turn - out .
# Generated: Eines ist sicher : Diese neuen Bestimmungen werden negative Auswirkungen auf die Wahlbeteiligung haben .
# Target: Eins ist sicher : diese neuen Bestimmungen werden sich negativ auf die Wahlbeteiligung auswirken .
# @@@@@@@@@@@@@
# Source: In this sense , the measures will partially undermine the American democratic system .
# Generated: In diesem Sinne werden die Maßnahmen das demokratische System der USA teilweise untergraben .
# Target: In diesem Sinne untergraben diese Maßnahmen teilweise das demokratische System der USA .
# @@@@@@@@@@@@@
# Source: Unlike in Canada , the American States are responsible for the organisation of federal elections in the United States .
# Generated: Im Gegensatz zu Kanada sind die USA fur die Durchfuhrung von Bundestagswahlen in den USA verantwortlich .
# Target: Im Gegensatz zu Kanada sind die US - Bundesstaaten fur die Durchfuhrung der Wahlen in den einzelnen Staaten verantwortlich .
# @@@@@@@@@@@@@
# Source: It is in this spirit that a majority of American governments have passed new laws since 2009 making the registration or voting process more difficult .
# Generated: In diesem Sinne hat eine Mehrheit der amerikanischen Regierungen seit 2009 neue Gesetze verabschiedet , die den Registrierungs - oder Abstimmungsprozess erschweren .
# Target: In diesem Sinne hat die Mehrheit der amerikanischen Regierungen seit 2009 neue Gesetze verkundet , die das Verfahren fur die Registrierung oder den Urnengang erschweren .
# @@@@@@@@@@@@@
# Source: This phenomenon gained momentum following the November 2010 elections , which saw 675 new Republican representatives added in 26 States .
# Generated: Dieses Phanomen hat nach den Wahlen im November 2010 , bei denen 675 neue republikanische Vertreter in 26 Staaten hinzukamen , an Dynamik gewonnen .
# Target: Dieses Phanomen hat nach den Wahlen vom November 2010 an Bedeutung gewonnen , bei denen 675 neue republikanische Vertreter in 26 Staaten verzeichnet werden konnten .
# @@@@@@@@@@@@@
# Source: As a result , 180 bills restricting the exercise of the right to vote in 41 States were introduced in 2011 alone .
# Generated: Damit wurden allein 2011 180 Rechnungen eingefuhrt , die die Ausubung des Stimmrechts in 41 Staaten einschranken .
# Target: Infolgedessen wurden 180 Gesetzesentwurfe allein im Jahr 2011 eingefuhrt , die die Ausubung des Wahlrechts in 41 Staaten einschranken .
# @@@@@@@@@@@@@
# Source: The new election laws require voters to show a photo ID card and proof of US citizenship .
# Generated: Die neuen Wahlgesetze sehen vor , dass die Wahler einen Personalausweis und einen Nachweis der US - Staatsburgerschaft vorlegen .
# Target: Die neuen Wahlgesetze verlangen , dass die Wahler einen Lichtbildausweis und einen Nachweis der US - Staatsburgerschaft vorlegen .
# @@@@@@@@@@@@@
# Source: Furthermore , these laws also reduce early voting periods , invalidate the right to register as a voter on election day and withdraw the right to vote of citizens with a criminal record .
# Generated: Daruber hinaus verringern diese Gesetze auch die vorzeitigen Abstimmungsfristen , ungultig das Recht , sich am Wahltag als Wahler anzumelden und das Wahlrecht der Burger mit einem Strafregister zuruckzuziehen .
# Target: Daruber hinaus werden durch diese Gesetze ebenfalls die Zeitraume fur die vorzeitige Stimmabgabe verkurzt , das Recht fur ungultig erklart , sich am Wahltag als Wahler zu registrieren , und Staatsburgern das Wahlrecht abgesprochen , fur die eine Gerichtsakte vorliegt .
# @@@@@@@@@@@@@
# Source: Before the 2006 elections , no US State required voters to show a photo ID card .
# Generated: Vor den Wahlen 2006 forderte kein US - Staat die Wahler auf , einen Personalausweis zu zeigen .
# Target: Vor den Wahlen von 2006 hat kein US - Staat von den Wahlern verlangt , einen Lichtbildausweis vorzuzeigen .
# @@@@@@@@@@@@@
# Source: Indiana was the first State to impose such a requirement .
# Generated: Indiana war der erste Staat , der eine solche Anforderung stellte .
# Target: Indiana war der erste Bundesstaat , der eine derartige Forderung erhoben hat .
# @@@@@@@@@@@@@
# Source: In 2008 , the Supreme Court of the United States upheld the constitutionality of the Indiana law .
# Generated: 2008 hat der Oberste Gerichtshof der Vereinigten Staaten die Verfassungsmaßigkeit des Indiana - Gesetzes bestatigt .
# Target: Der Oberste Gerichtshof der Vereinigten Staaten bestatigte im Jahr 2008 die Verfassungsmaßigkeit des Gesetzes von Indiana .
# @@@@@@@@@@@@@
# Source: The Republican authorities were quick to extend this practice to other States .
# Generated: Die republikanischen Behorden haben diese Praxis schnell auf andere Staaten ausgeweitet .
# Target: Die republikanischen Behorden beeilten sich , diese Praxis auf andere Staaten auszudehnen .
# @@@@@@@@@@@@@
# Source: Over the past two years , they sponsored bills in 34 States to force voters to show a photo ID card .
# Generated: In den letzten zwei Jahren unterstutzten sie in 34 Staaten Rechnungen , um die Wahler zu zwingen , eine Foto - ID - Karte zu zeigen .
# Target: Im Laufe der letzten beiden Jahre forderten sie in 34 Bundesstaaten Gesetzesentwurfe , mit denen die Wahler gezwungen werden , einen Lichtbildausweis vorzuzeigen .
# @@@@@@@@@@@@@
# Source: It is important to note that , unlike Quebec , American citizens do not have a universal ID card such as the health insurance card .
# Generated: Es ist wichtig zu beachten , dass die amerikanischen Burger im Gegensatz zu Quebec keine universelle Ausweise wie die Krankenversicherungskarte haben .
# Target: Es ist wichtig anzumerken , dass die US - Burger im Gegensatz zu Quebec nicht uber eine universelle Ausweiskarte wie die Krankenversicherungskarte verfugen .
# @@@@@@@@@@@@@
# Source: In fact , 11 % of American citizens , i . e . 21 million people of voting age , do not possess a photo ID card issued by a government agency of their State .
# Generated: Tatsachlich verfugen 11 % der amerikanischen Burger , d . h . 21 Millionen Menschen im Wahlalter , nicht uber einen von einer staatlichen Behorde ihres Staates ausgestellten Personalausweis .
# Target: In der Tat besitzen 11 % der US - Burger , d . h . 21 Millionen wahlberechtigte Personen keinen von einer Regierungsbehorde ihres Staates ausgestellten Lichtbildausweis .
# @@@@@@@@@@@@@
# Source: In addition , five million new voters in 2012 do not have such identification .
# Generated: Daruber hinaus haben 2012 funf Millionen neue Wahler keine solche Kennzeichnung .
# Target: Daruber hinaus verfugen funf Millionen Neuwahler im Jahr 2012 nicht uber einen derartigen Ausweis .
# @@@@@@@@@@@@@
# Source: And it often costs over a hundred dollars to obtain the required identity card .
# Generated: Und oft kostet es mehr als hundert Dollar , um den gewunschten Personalausweis zu erhalten .
# Target: Allerdings sind haufig mehr als hundert Dollar zu zahlen , um den erforderlichen Ausweis zu erhalten .
# @@@@@@@@@@@@@
# Source: The new restrictions disproportionately affect young people , minorities and people with low incomes .
# Generated: Die neuen Beschrankungen betreffen uberproportional junge Menschen , Minderheiten und Menschen mit niedrigem Einkommen .
# Target: Von den neuen Einschrankungen sind junge Menschen , Minderheiten und Menschen mit niedrigem Einkommen unverhaltnismaßig stark betroffen .
# @@@@@@@@@@@@@
# Source: In fact , 25 % of African Americans , 15 % of those earning less than $ 35 , 000 ; 18 % of citizens over 65 and 20 % of voters 18 to 29 years old do not have the required photo ID card .
# Generated: Tatsachlich haben 25 % der Afrikaner , 15 % der Menschen , die weniger als 35 . 000 Dollar verdienen ; 18 % der Burger uber 65 und 20 % der 18 - bis 29 - jahrigen Wahler nicht die erforderliche Ausweiskarte .
# Target: In der Tat verfugen 25 % der Afro - Amerikaner , 15 % der Personen mit einem Einkommen von weniger als $ 35 . 000 , 18 % der Burger uber 65 Jahre und 20 % der Wahler zwischen 18 und 29 Jahren nicht uber den erforderlichen Lichtbildausweis .
# @@@@@@@@@@@@@
# Source: And that ' s not all .
# Generated: Und das ist nicht alles .
# Target: Dies reicht noch weiter .
# @@@@@@@@@@@@@
# Source: Students , voters considered to be voting more for Democratic candidates , are not allowed in several States to use the photo ID card issued by their institution .
# Generated: Studenten , Wahler , die fur mehr fur demokratische Kandidaten stimmen , sind in mehreren Staaten nicht erlaubt , die von ihrer Institution ausgestellte Fotokarte zu verwenden .
# Target: Den Studenten , die als Wahler angesehen werden , die ihre Stimme vermehrt fur demokratische Kandidaten abgeben , ist es in mehreren Staaten nicht erlaubt , ihren von ihrer Einrichtung ausgestellten Lichtbildausweis zu benutzen .
# @@@@@@@@@@@@@
# Source: On the other hand , these same States allow fishing or hunting club members , who vote more Republican , to use the cards issued by these clubs when they vote .
# Generated: Auf der anderen Seite erlauben dieselben Staaten den Mitgliedern der Fischerei - oder Jagdclubs , die mehr Republikaner wahlen , die von diesen Vereinen ausgestellten Karten zu verwenden , wenn sie abstimmen .
# Target: Andererseits erlauben dieselben Staaten es Mitgliedern von Angel - oder Jagdvereinen , die starker fur die republikanische Seite wahlen , die von diesen Vereinen ausgestellten Karten fur Wahlen zu benutzen .
# @@@@@@@@@@@@@
# Source: Prior to 2004 , no State required proof of citizenship to vote .
# Generated: Vor 2004 hat kein Staat einen Nachweis uber die Staatsburgerschaft verlangt , um abzustimmen .
# Target: Vor 2004 hat kein Bundesstaat fur das Wahlen einen Nachweis der Staatsburgerschaft gefordert .
# @@@@@@@@@@@@@
# Source: Arizona was the first to introduce such a requirement .
# Generated: Arizona war der erste , der eine solche Anforderung einfuhrte .
# Target: Arizona war der erste Bundesstaat , der eine derartige Forderung einfuhrte .
# @@@@@@@@@@@@@
# Source: Since 2011 , a dozen States have adopted laws requiring voters to prove they are American citizens .
# Generated: Seit 2011 haben ein Dutzend Staaten Gesetze verabschiedet , die den Wahlern nachweisen , dass sie amerikanische Burger sind .
# Target: Seit 2011 haben ein Dutzend Staaten Gesetze verabschiedet , die von den Wahlern fordern , dass sie ihre US - Staatsburgerschaft nachweisen .
# @@@@@@@@@@@@@
# Source: These measures are clearly intended to limit the Hispanic vote .
# Generated: Diese Maßnahmen zielen eindeutig darauf ab , die hispanische Abstimmung zu begrenzen .
# Target: Diese Maßnahmen zielen deutlich darauf ab , die hispanischen Stimmen zu begrenzen .
# @@@@@@@@@@@@@
# Source: However , it appears that two out of three Hispanic voters favour the Democratic party .
# Generated: Es scheint jedoch , dass zwei von drei hispanischen Wahlern die Demokratische Partei bevorzugen .
# Target: Denn es liegt auf der Hand , dass zwei von drei hispanischen Wahlern , die demokratische Partei bevorzugen .
# @@@@@@@@@@@@@
# Source: What is more , in 2011 Republican legislators sponsored laws abolishing the registration of voters on election day in eight States .
# Generated: Daruber hinaus haben die republikanischen Gesetzgeber 2011 Gesetze zur Abschaffung der Wahlerregistrierung in acht Staaten finanziert .
# Target: Daruber hinaus haben republikanische Gesetzgeber 2011 in acht Bundesstaaten Gesetze gefordert , mit denen die Registrierung von Wahlern am Wahltag abgeschafft wurde .
# @@@@@@@@@@@@@
# Source: In addition , they limited the right of individuals and groups to provide assistance to voters wishing to register .
# Generated: Daruber hinaus beschrankten sie das Recht von Einzelpersonen und Gruppen , Wahlern , die sich registrieren lassen wollen , Unterstutzung zu gewahren .
# Target: Daruber hinaus haben Sie das Recht von Einzelpersonen und Gruppen beschrankt , jenen Wahlern Hilfestellung zu leisten , die sich registrieren mochten .
# @@@@@@@@@@@@@
# Source: These restrictions are not without consequence .
# Generated: Diese Einschrankungen sind nicht ohne Folgen .
# Target: Diese Einschrankungen sind nicht ohne Folgen .
# @@@@@@@@@@@@@
# Source: For example , during the 2004 general election , voter registration campaigns contributed to registering around 10 million citizens .
# Generated: So trugen zum Beispiel wahrend der Parlamentswahlen 2004 Wahlkampfe zur Registrierung von etwa 10 Millionen Burgern bei .
# Target: Beispielsweise haben die Kampagnen zur Wahlerregistrierung bei den allgemeinen Wahlen 2004 dazu beigetragen , ca . 10 Mio . Staatsburger zu registrieren .
# @@@@@@@@@@@@@
# Source: However , the measures adopted since 2009 have led to a 17 % drop in the registration rate of new voters in 2010 compared to 2006 .
# Generated: Die seit 2009 angenommenen Maßnahmen haben jedoch im Vergleich zu 2006 zu einem Ruckgang der Registrierungsquote neuer Wahler um 17 % gefuhrt .
# Target: Denn durch die seit 2009 verabschiedeten Maßnahmen hat sich der Anteil der Registrierung von Neuwahlern 2010 im Vergleich zu 2006 um 17 % verringert .
# @@@@@@@@@@@@@
# Source: In addition , Republican legislators have enacted laws in five other States aimed at reducing the early voting period .
# Generated: Daruber hinaus haben die republikanischen Gesetzgeber in funf anderen Staaten Gesetze erlassen , die darauf abzielen , die Vorabwahl zu verkurzen .
# Target: Außerdem haben die republikanischen Gesetzgeber in funf weiteren Bundesstaaten Gesetze verabschiedet , die darauf abzielen , den Zeitraum fur die vorzeitige Stimmabgabe zu verkurzen .
# @@@@@@@@@@@@@
# Source: For example , during the 2008 general election in Florida , 33 % of early voters were African - Americans , who accounted however for only 13 % of voters in the State .
# Generated: Wahrend der Parlamentswahlen 2008 in Florida waren beispielsweise 33 % der fruhen Wahler Afroamerikaner , die jedoch nur 13 % der Wahler im Staat ausmachten .
# Target: Beispielsweise waren bei den allgemeinen Wahlen 2008 in Florida 33 % der Wahler , die im Voraus gewahlt haben , Afro - Amerikaner , obwohl sie nur 13 % der Wahler des Bundesstaates ausmachen .
# @@@@@@@@@@@@@
# Source: The same applied to Hispanics .
# Generated: Dasselbe gilt fur Hispanics .
# Target: Gleiches gilt fur die hispanische Bevolkerung .
# @@@@@@@@@@@@@
# Source: These represented only 11 % of voters , but 24 % of citizens who voted early .
# Generated: Sie reprasentierten nur 11 % der Wahler , aber 24 % der Burger , die fruher gewahlt haben .
# Target: Letztere machte nur 11 % der Wahler aus , aber 24 % der Burger , die im Voraus gewahlt haben .
# @@@@@@@@@@@@@
# Source: On the other hand , 76 % of voters were white but these represented only 46 % of early voters .
# Generated: Andererseits waren 76 % der Wahler weiß , aber nur 46 % der fruhen Wahler .
# Target: Im Gegensatz dazu machten die Weißen , die 76 % der Wahler darstellten , nur 46 % der Wahler aus , die im Voraus wahlten .
# @@@@@@@@@@@@@
# Source: Of course , Democratic legislators and their supporters vigorously opposed the adoption of laws restricting voter registration .
# Generated: Naturlich haben sich demokratische Gesetzgeber und ihre Anhanger entschieden gegen die Verabschiedung von Gesetzen zur Beschrankung der Wahlerregistrierung ausgesprochen .
# Target: Naturlich haben sich die demokratischen Gesetzgeber und ihre Anhanger energisch der Verabschiedung von Gesetzen entgegengestellt , die die Registrierung der Wahler einschranken .
# @@@@@@@@@@@@@
# Source: Several bills were blocked by vetoes of Democratic governors .
# Generated: Mehrere Rechnungen wurden durch Vetos demokratischer Gouverneure blockiert .
# Target: Mehrere Gesetzesentwurfe wurden durch die Vetos der demokratischen Gouverneure blockiert .
# @@@@@@@@@@@@@
# Source: The United States Attorney General intervened to suspend the most controversial laws .
# Generated: Der Generalstaatsanwalt der Vereinigten Staaten intervenierte , um die umstrittensten Gesetze auszusetzen .
# Target: Der Generalanwalt der USA hat eingegriffen , um die umstrittensten Gesetze auszusetzen .
# @@@@@@@@@@@@@
# Source: They were able to partially limit the damage .
# Generated: Sie konnten den Schaden teilweise begrenzen .
# Target: Sie konnten die Schaden teilweise begrenzen .
# @@@@@@@@@@@@@
# Source: For example , only 16 out of 34 States have adopted laws requiring the presentation of a photo ID card .
# Generated: So haben beispielsweise nur 16 von 34 Staaten Gesetze verabschiedet , die die Vorlage einer Fotokarte vorschreiben .
# Target: Beispielsweise haben nur 16 der 34 Bundesstaaten Gesetze verabschiedet , die das Vorzeigen eines Lichtbildausweises verlangen .
# @@@@@@@@@@@@@
# Source: However , the new rules put in place will undoubtedly make it more difficult to exercise the right to vote in 2012 .
# Generated: Die neuen Regeln werden es jedoch zweifellos schwieriger machen , 2012 das Wahlrecht auszuuben .
# Target: Allerdings werden die neu eingefuhrten Regeln im Jahr 2012 zweifellos die Ausubung des Wahlrechts erschweren .
# @@@@@@@@@@@@@
# Source: Democratic critics denounce the partisan character of the laws that have been passed and they see a clear objective of influencing the 2012 results in key States .
# Generated: Demokratische Kritiker prangern den parteiischen Charakter der verabschiedeten Gesetze an , und sie sehen ein klares Ziel der Einflussnahme auf die wichtigsten Staaten von 2012 .
# Target: Die demokratischen Kritiker prangern die parteipolitische Natur der verabschiedeten Gesetze an und sehen in ihnen als klares Ziel die Beeinflussung der Ergebnisse in den fur 2012 ausschlaggebenden Staaten .
# @@@@@@@@@@@@@
# Source: A 2011 Brennan Centre report shows that the States that have adopted these laws represent 171 of the 270 votes needed in the electoral college to win the Presidency .
# Generated: Ein Brennan - Centre - Bericht aus dem Jahr 2011 zeigt , dass die Staaten , die diese Gesetze verabschiedet haben , 171 der 270 Stimmen reprasentieren , die im Wahlkolleg benotigt werden , um den Ratsvorsitz zu gewinnen .
# Target: Ein Bericht des Brennan Centers von 2011 zeigt , dass diejenigen Staaten , die diese Gesetze verabschiedet haben , 171 der 270 Stimmen ausmachen , die im Wahlmannergremium erforderlich sind , um die Prasidentschaft zu gewinnen .
# @@@@@@@@@@@@@
# Source: It is too early to say with certainty that these legislative changes in the electoral system will have significant impacts on the outcome of the 2012 presidential elections .
# Generated: Es ist noch zu fruh , um mit Sicherheit zu sagen , dass diese Gesetzesanderungen im Wahlsystem erhebliche Auswirkungen auf das Ergebnis der Prasidentschaftswahlen 2012 haben werden .
# Target: Es ist zu fruh , um mit Gewissheit zu bestatigen , dass diese Anderungen der Rechtsvorschriften am Wahlsystem erhebliche Auswirkungen auf das Ergebnis der Prasidentschaftswahlen im Jahr 2012 haben werden .
# @@@@@@@@@@@@@
# Source: But one thing is certain : these new provisions will have a negative impact on the turn - out .
# Generated: Eines ist jedoch sicher : Diese neuen Bestimmungen werden negative Auswirkungen auf die Umstellung haben .
# Target: Aber eins ist sicher : diese neuen Bestimmungen werden sich negativ auf die Wahlbeteiligung auswirken .
# @@@@@@@@@@@@@
# Source: In this sense , the measures will partially undermine the American democratic system .
# Generated: In diesem Sinne werden die Maßnahmen das demokratische System der USA teilweise untergraben .
# Target: In diesem Sinne untergraben diese Maßnahmen teilweise das demokratische System der USA .
# @@@@@@@@@@@@@
# Source: Prostate cancer screening : take the test or not ?
# Generated: Prostatakrebs - Screening : Nehmen Sie den Test oder nicht ?
# Target: Prostatakrebsfruherkennung : sollte der Test gemacht werden oder nicht ?
# @@@@@@@@@@@@@
# Source: Indeed , the PSA test sometimes shows erroneous results with false negative or even false positive results , which involve unnecessary medical interventions .
# Generated: Tatsachlich zeigt der PSA - Test manchmal fehlerhafte Ergebnisse mit falschen negativen oder sogar falschen positiven Ergebnissen , die unnotige medizinische Eingriffe mit sich bringen .
# Target: Der PSA - Test weise in der Tat manchmal fehlerhafte Ergebnisse auf , mit falschen negativen oder aber auch falschen positiven Ergebnissen , die zu unnotigen medizinischen Eingriffen fuhren .
# @@@@@@@@@@@@@
# Source: Enough to make already reluctant men hesitate to take screening tests .
# Generated: Genug , bereits widerwillige Manner zogern , Screening - Tests durchzufuhren .
# Target: Dies fuhrt zu starkerem Zogern der bereits unentschlossenen Manner fur die Durchfuhrung von Fruherkennungstests .
# @@@@@@@@@@@@@
# Source: Take the test or not ?
# Generated: Nehmen Sie den Test oder nicht ?
# Target: Sollte der Test gemacht werden oder nicht ?
# @@@@@@@@@@@@@
# Source: We asked two specialists for their opinion .
# Generated: Wir haben zwei Spezialisten um ihre Meinung gebeten .
# Target: Wir haben die Meinung von zwei Facharzten eingeholt .
# @@@@@@@@@@@@@
# Source: In studies conducted in the United States , there was a lot of contamination between control groups , so it is difficult to interpret the data and make firm recommendations .
# Generated: In den USA durchgefuhrten Studien gab es eine große Kontamination zwischen Kontrollgruppen , so dass es schwierig ist , die Daten zu interpretieren und konkrete Empfehlungen zu geben .
# Target: Bei den in den USA durchgefuhrten Studien bestanden zahlreiche Storfaktoren zwischen den Kontrollgruppen , sodass es schwierig ist , diese Daten zu interpretieren und eindeutige Empfehlungen zu geben .
# @@@@@@@@@@@@@
# Source: Another study , this time a European one , concluded that there was a difference in mortality between patients who were screened and those who were not .
# Generated: Eine weitere Studie , diesmal eine europaische Studie , kam zu dem Schluss , dass es einen Unterschied in der Sterblichkeit zwischen Patienten gab , die untersucht wurden , und denen , die nicht .
# Target: Eine weitere Studie , dieses Mal aus Europa , kam zu der Schlussfolgerung , dass ein Unterschied bei der Sterblichkeit von Patienten mit und ohne Fruherkennung besteht .
# @@@@@@@@@@@@@
# Source: This study also showed , with a follow - up after 12 years , that it is between 30 and 40 % more likely for metastases to occur in the absence of screening .
# Generated: Diese Studie hat auch gezeigt , dass es nach 12 Jahren 30 bis 40 % mehr Metastasen gibt , wenn kein Screening stattfindet .
# Target: Diese Studie hat ebenfalls gezeigt , dass bei einer Nachbeobachtung nach 12 Jahren die Wahrscheinlichkeit der Bildung von Metastasen um 30 bis 40 % hoher ist , wenn keine Fruherkennung durchgefuhrt wurde .
# @@@@@@@@@@@@@
# Source: I therefore recommend the test from age 50 , or 40 if you have a direct relative who previously had prostate cancer .
# Generated: Ich empfehle daher den Test ab 50 , oder 40 , wenn Sie einen direkten Verwandten , der zuvor Prostatakrebs hatte .
# Target: Deshalb empfehle ich den Test ab einem Alter von 50 Jahren bzw . 40 Jahren , wenn man einen direkten Verwandten hat , der bereits an Prostatakrebs erkrankt war .
# @@@@@@@@@@@@@
# Source: African - American men are also more at risk .
# Generated: Afrikanisch - amerikanische Manner sind ebenfalls starker gefahrdet .
# Target: Bei Mannern afro - amerikanischer Herkunft besteht ebenfalls ein hoheres Risiko .
# @@@@@@@@@@@@@
# Source: The key is to make the right decision once cancer has been detected .
# Generated: Der Schlussel liegt in der richtigen Entscheidung , sobald Krebs festgestellt wurde .
# Target: Das Wichtigste ist , die richtige Entscheidung zu treffen , sobald eine Krebserkrankung erkannt wurde .
# @@@@@@@@@@@@@
# Source: There are aggressive cancers and others that are indolent .
# Generated: Es gibt aggressive Krebserkrankungen und andere , die untatig sind .
# Target: Es gibt Krebsarten , die aggressiv und andere , die indolent sind .
# @@@@@@@@@@@@@
# Source: The patient really needs to be made to understand the degree of risk of his cancer , by offering him the options available , not necessarily treating prostate cancers that are not long - term life threatening , and opting instead , in such cases , for active monitoring of the disease .
# Generated: Der Patient muss wirklich den Grad seines Krebsrisikos begreifen , indem er ihm die zur Verfugung stehenden Moglichkeiten bietet , nicht unbedingt Prostatakrebs behandeln , die nicht langfristig lebensbedrohlich sind , und sich stattdessen in solchen Fallen fur eine aktive Uberwachung der Krankheit entscheiden .
# Target: Dem Patienten muss das Ausmaß des Risikos seiner Krebserkrankung wirklich verstandlich gemacht werden , indem ihm die moglichen Optionen aufgezeigt werden , bei denen Prostatakrebse unbehandelt bleiben kann , wenn er die Lebensqualitat auf lange Sicht nicht beeintrachtigt , und man sich in diesen Fallen eher fur eine aktive Uberwachung der Krankheit entscheidet .
# @@@@@@@@@@@@@
# Source: Today , many men in whom cancer has been detected will not be treated because their cancer is not aggressive and is not life threatening .
# Generated: Heute werden viele Manner , bei denen Krebs festgestellt wurde , nicht behandelt , weil ihr Krebs nicht aggressiv ist und nicht lebensbedrohlich ist .
# Target: Heute findet bei vielen Mannern , bei denen man Krebs erkannt hat , keine Behandlung statt , da ihr Krebs nicht aggressiv ist und keine Bedrohung fur ihr Leben darstellt .
# @@@@@@@@@@@@@
# Source: Active monitoring will be suggested , and if the disease progresses , they will be offered treatment .
# Generated: Eine aktive Uberwachung wird empfohlen , und wenn die Krankheit voranschreitet , wird ihnen eine Behandlung angeboten .
# Target: Man schlagt ihnen eine aktive Uberwachung vor und bietet ihnen bei Fortschreiten der Krankheit eine Behandlung an .
# @@@@@@@@@@@@@
# Source: More and more , specific criteria are being determined in order to decide who should or should not be treated .
# Generated: Immer mehr werden spezifische Kriterien festgelegt , um zu entscheiden , wer behandelt werden soll oder nicht .
# Target: Man bestimmt mit zunehmender Genauigkeit die Kriterien fur eine Entscheidung , wer behandelt werden sollte und wer nicht .
# @@@@@@@@@@@@@
# Source: Therefore I recommend taking the test .
# Generated: Daher empfehle ich , den Test durchzufuhren .
# Target: Deshalb empfehle ich trotzdem die Durchfuhrung des Tests .
# @@@@@@@@@@@@@
# Source: But the important thing is to have a discussion with your doctor to determine whether or not to take it .
# Generated: Aber das Wichtigste ist , eine Diskussion mit Ihrem Arzt zu fuhren , um zu entscheiden , ob es nehmen oder nicht .
# Target: Am wichtigsten ist es aber , mit seinem Arzt zu sprechen , um zu bestimmen , ob er durchgefuhrt werden sollte oder nicht .
# @@@@@@@@@@@@@
# Source: In collaboration with the Societe internationale d ' urologie SIU , Movember has created a tool that makes it possible to evaluate the pros and cons of the PSA test .
# Generated: Movember hat in Zusammenarbeit mit der Societe internationale d ' urologie CrespSIU ein Tool entwickelt , das es ermoglicht , die Vor - und Nachteile des PSA - Tests zu bewerten .
# Target: In Zusammenarbeit mit der internationalen Gesellschaft fur Urologie hat Movember ein Instrument entwickelt , mit dem es moglich ist , die Vor - und Nachteile des PSA - Tests zu bewerten .
# @@@@@@@@@@@@@
# Source: You can download the document ( in English for the time being , a French translation will be available shortly ) at this address : http : / / ca . movember . com / fr / mens - health / prostate - cancer - screening
# Generated: Sie konnen das Dokument ( vorlaufig in englischer Sprache ) unter dieser Adresse herunterladen : http : / / ca . movember . com / fr / mens - health / prostate - cancer - screening - screening .
# Target: Dieses Dokument ( derzeit nur auf Englisch , aber eine Ubersetzung wird in Kurze verfugbar sein ) kann unter folgender Adresse heruntergeladen werden : http : / / ca . movember . com / fr / mens - health / prostate - cancer - screening
# @@@@@@@@@@@@@
# Source: Preventing the disease
# Generated: Verhinderung der Krankheit
# Target: Vorbeugen der Krankheit
# @@@@@@@@@@@@@
# Source: Unfortunately , there is no miracle recipe for preventing cancer .
# Generated: Leider gibt es kein Wunderrezept zur Pravention von Krebs .
# Target: Leider gibt es kein Wundermittel zur Vorbeugung von Krebs .
# @@@@@@@@@@@@@
# Source: Despite the progress in research , the adoption of healthy living habits remains the best way to reduce the risk of suffering from it .
# Generated: Trotz des Fortschritts in der Forschung bleibt die Annahme gesunder Lebensgewohnheiten der beste Weg , das Risiko zu verringern , darunter zu leiden .
# Target: Trotz der Fortschritte in der Forschung bleibt die Annahme einer gesunden Lebensweise der beste Weg , um das Risiko zu verringern , an ihm zu erkranken .
# @@@@@@@@@@@@@
# Source: It is estimated that if everyone ate well and exercised enough , 30 % of cancers could be prevented .
# Generated: Schatzungen zufolge konnten 30 % der Krebserkrankungen verhindert werden , wenn alle gut ausgehen und ausgenutzt werden .
# Target: Es wird geschatzt , dass 30 % der Krebserkrankungen verhindert werden konnten , wenn alle gut essen und sich ausreichend bewegen wurden .
# @@@@@@@@@@@@@
# Source: " If no more people smoked , this rate would increase to at least 50 % , " says Andre Beaulieu , spokesman for the Canadian Cancer Society .
# Generated: " Wenn nicht mehr Menschen geraucht wurden , wurde diese Rate auf mindestens 50 % steigen " , sagt Andre Beaulieu , Sprecher der Canadian Cancer Society .
# Target: " Wenn es keine Raucher mehr gabe , wurde dieser Wert mindestens auf 50 % ansteigen " , betont Andre Beaulieu , Sprecher der kanadischen Krebsgesellschaft .
# @@@@@@@@@@@@@
# Source: On the other hand , it is estimated that roughly 10 % of cancers are hereditary .
# Generated: Andererseits wird geschatzt , dass etwa 10 % der Krebserkrankungen erblich sind .
# Target: Allerdings wird davon ausgegangen , dass etwa 10 % der Krebserkrankungen durch Vererbung verursacht werden .
# @@@@@@@@@@@@@
# Source: Some are also completely unexplained .
# Generated: Einige sind auch vollig unerklarlich .
# Target: Mehrere bleiben auch vollig ungeklart .
# @@@@@@@@@@@@@
# Source: For the Canadian Cancer Society , the fight against tobacco remains a priority , despite the decrease in the number of smokers .
# Generated: Fur die kanadische Krebsgesellschaft ist der Kampf gegen Tabak nach wie vor eine Prioritat , obwohl die Zahl der Raucher abnimmt .
# Target: Fur die kanadische Krebsgesellschaft bleibt der Kampf gegen die Tabakabhangigkeit eine Prioritat , trotz des Ruckgangs der Zahl der Raucher .
# @@@@@@@@@@@@@
# Source: Cigarettes are linked to 85 % of lung cancer cases .
# Generated: Zigaretten sind an 85 % der Lungenkrebsfalle gebunden .
# Target: Das Rauchen ist verantwortlich fur 85 % der Falle von Lungenkrebs .
# @@@@@@@@@@@@@
# Source: It is also a risk factor for a number of others .
# Generated: Es ist auch ein Risikofaktor fur einige andere .
# Target: Es ist auch ein Risikofaktor fur mehrere andere Krebsarten .
# @@@@@@@@@@@@@
# Source: This massively damages people ' s health .
# Generated: Dies schadet der Gesundheit der Menschen massiv .
# Target: Es schadigt stark die Gesundheit der Menschen .
# @@@@@@@@@@@@@
# Source: " Even today , there are 1 . 5 million smokers in Quebec " deplores spokesperson Andre Beaulieu .
# Generated: " Auch heute gibt es in Quebec 1 , 5 Millionen Raucher " , so Andre Beaulieu .
# Target: " Heute noch gibt es in Quebec 1 , 5 Mio . Raucher " , bedauert der Sprecher Andre Beaulieu .
# @@@@@@@@@@@@@
# Source: Encouraging data : 10 years after giving up smoking , the risk of dying from cancer drops by half .
# Generated: Ermutigen Sie Daten : 10 Jahre nach dem Verzicht auf das Rauchen sinkt das Risiko , an Krebs zu sterben um die Halfte .
# Target: Ermutigende Daten : 10 Jahre nach dem Verzicht auf die Zigarette , verringert sich das Risiko an Krebs zu sterben um die Halfte .
# @@@@@@@@@@@@@
# Source: Overweight and obesity are also conducive to the onset of the disease , according to the SCC .
# Generated: Ubergewicht und Fettleibigkeit sind laut SCC auch der Entstehung der Krankheit forderlich .
# Target: Gemaß der kanadischen Krebsgesellschaft fordern Ubergewicht und Adipositas ebenfalls den Ausbruch der Krankheit .
# @@@@@@@@@@@@@
# Source: They can increase the risks of cancer of the breast , colon and rectum , oesophagus , pancreas and uterus .
# Generated: Sie konnen die Krebsgefahr von Brust , Kolon und Rektum , Speiserohre , Bauchspeicheldruse und Gebarmutter erhohen .
# Target: Sie scheinen das Risiko fur Brust - , Grimmdarm - , Mastdarm - , Speiserohren - , Bauchspeicheldrusen - und Gebarmutterkrebs zu erhohen .
# @@@@@@@@@@@@@
# Source: " Research shows that the regular practice of physical activity throughout your life protects against colon cancer " it is also said .
# Generated: " Forschung zeigt , dass die regelmaßige Praxis der korperlichen Aktivitat wahrend Ihres Lebens schutzt vor Colon Krebs " , wird auch gesagt .
# Target: " Die Forschung zeigt , dass eine regelmaßige korperliche Aktivitat wahrend des gesamten Lebens gegen Grimmdarmkrebs schutzt " , fugt er hinzu .
# @@@@@@@@@@@@@
# Source: The organisation also recommends limiting your consumption of red meat .
# Generated: Die Organisation empfiehlt Ihnen auch , den Konsum von rotem Fleisch zu beschranken .
# Target: Die Organisation empfiehlt ebenfalls , den Verzehr von rotem Fleisch zu begrenzen .
# @@@@@@@@@@@@@
# Source: In large amounts , it increases the risks of developing colo - rectal cancer .
# Generated: In großen Mengen erhoht es das Risiko der Entwicklung von Kolo - Rektalkrebs .
# Target: In zu großer Menge erhoht es das Risiko , an einem Grimm - bzw . Mastdarmkrebs zu erkranken .
# @@@@@@@@@@@@@
# Source: Likewise , so do cured meat products , and these should be avoided .
# Generated: Genauso sollten auch geheizte Fleischprodukte vermieden werden .
# Target: Wurstwaren sollten ebenfalls gemieden werden .
# @@@@@@@@@@@@@
# Source: The conservation of meat by smoking , drying or curing can cause the formation of carcinogens .
# Generated: Die Erhaltung von Fleisch durch Rauchen , Trocknen oder Heilen kann die Bildung von krebserregenden Stoffen verursachen .
# Target: Die Konservierung von Fleisch durch Rauchern , Trocknen oder Salzen kann zur Bildung von Karzinogenen fuhren .
# @@@@@@@@@@@@@
# Source: " They can damage cells in the body and lead to the development of cancer " it is explained .
# Generated: " Sie konnen Zellen im Korper beschadigen und zur Entwicklung von Krebs fuhren " , erklart man .
# Target: " Letztere konnen die Korperzellen schadigen und zur Entwicklung von Krebs fuhren " , erklart er .
# @@@@@@@@@@@@@
# Source: Vitamins
# Generated: Vitamine
# Target: Vitamine
# @@@@@@@@@@@@@
# Source: In recent years , a number of scientists have studied the links between vitamin supplements and cancer .
# Generated: In den letzten Jahren haben mehrere Wissenschaftler die Verbindungen zwischen Vitaminzusatzen und Krebs untersucht .
# Target: In den letzten Jahren haben mehrere Wissenschaftler den Zusammenhang zwischen Vitaminzusatzen und Krebs untersucht .
# @@@@@@@@@@@@@
# Source: For the time being however their research is inconclusive .
# Generated: Zurzeit ist ihre Forschung jedoch nicht schlussig .
# Target: Ihre Untersuchungen sind aber derzeit nicht schlussig .
# @@@@@@@@@@@@@
# Source: Studies on vitamin E are contradictory , according to the SCC .
# Generated: Studien uber Vitamin E sind widerspruchlich , so der SCC .
# Target: Nach der kanadischen Krebsgesellschaft sind die Studien zu Vitamin E widerspruchlich .
# @@@@@@@@@@@@@
# Source: While one study noted a decrease in the risk of prostate cancer , another noted an increase .
# Generated: Obwohl eine Studie eine Verringerung des Risikos von Prostatakrebs vermerkte , stellte eine weitere eine Zunahme fest .
# Target: Wahrend eine Studie die Verringerung des Risikos von Prostatakrebs herausgefunden hat , zeigte eine andere eher eine Erhohung .
# @@@@@@@@@@@@@
# Source: Also the effect of vitamin D on cancer is not clear .
# Generated: Auch die Wirkung von Vitamin D auf Krebs ist nicht klar .
# Target: Die Wirkung von Vitamin D auf den Krebs wurde ebenfalls noch nicht deutlich aufgezeigt .
# @@@@@@@@@@@@@
# Source: In addition , Mr Beaulieu emphasises the importance of discussing your concerns and family history with your doctor .
# Generated: Daruber hinaus betont Herr Beaulieu , wie wichtig es ist , mit Ihrem Arzt uber Ihre Anliegen und Familiengeschichte zu sprechen .
# Target: Daruber hinaus betont Herr Beaulieu , wie wichtig es ist , mit seinem Arzt uber seine Bedenken und seine familiare Vorbelastung zu sprechen .
# @@@@@@@@@@@@@
# Source: " Taking a screening test doesn ' t give you cancer . "
# Generated: " Ein Screening - Test gibt Ihnen keinen Krebs " .
# Target: " Die Durchfuhrung eines Fruherkennungstest fuhrt nicht zu Krebs . "
# @@@@@@@@@@@@@
# Source: The Higgs boson revealed
# Generated: Der Boson Higgs
# Target: Das Higgs - Boson analysiert
# @@@@@@@@@@@@@
# Source: The announcement of the probable discovery of the Higgs boson created quite a stir last summer , and with good reason .
# Generated: Die Ankundigung der wahrscheinlichen Entdeckung des Higgs Bosones hat im letzten Sommer recht Aufregung ausgelost , und zwar aus gutem Grund .
# Target: Die Ankundigung der wahrscheinlichen Entdeckung des Higgs - Bosons hat im letzten Sommer ein gewisses Aufsehen erregt , und dies aus gutem Grund .
# @@@@@@@@@@@@@
# Source: Indeed , it is believed that this boson is part of the mechanism responsible for the mass of everything in the Universe , no less .
# Generated: Tatsachlich wird angenommen , dass dieser Boson Teil des Mechanismus ist , der fur die Masse von allem im Universum verantwortlich ist , nicht weniger .
# Target: Man glaubt in der Tat , dass dieses Boson an nichts weniger als am Mechanismus beteiligt ist , der fur die Masse aller Objekte im Universum verantwortlich ist .
# @@@@@@@@@@@@@
# Source: Also it is the last particle whose existence is predicted by the Standard Model - our best or " less worse " explanation of the nature and behaviour of matter - but which has not yet been observed empirically .
# Generated: Es ist auch der letzte Teilchen , dessen Existenz durch das Standard - Modell vorhergesagt wird - unsere beste oder " weniger schlechtere " Erklarung der Art und des Verhaltens von Materie - , die aber noch nicht empirisch beobachtet wurde .
# Target: Und schließlich handelt es sich um das letzte Teilchen , dessen Existenz vom Standardmodell - unserer besten oder " am wenigsten falschen " Erklarung der Natur und dem Verhalten der Materie - vorausgesagt , aber empirisch noch nicht beobachtet wurde .
# @@@@@@@@@@@@@
# Source: But for physicists , it is still not completely sure that it really is the Higgs .
# Generated: Aber fur Physiker ist es immer noch nicht ganz sicher , dass es wirklich die Higgs ist .
# Target: Aber fur die Physiker ist es noch nicht vollstandig sicher , dass es sich wirklich um das Higgs handelt .
# @@@@@@@@@@@@@
# Source: We know without a shadow of a doubt that it is a new authentic particle , and greatly resembles the Higgs boson predicted by the Standard Model .
# Generated: Wir wissen ohne jeden Zweifel , dass es sich um eine neue authentische Partikel handelt , die den Higgs Boson ahnelt , der vom Standard Model vorhergesagt wurde .
# Target: Wir wissen ohne den Schatten eines Zweifels , dass wir ein echtes neues Teilchen haben , und dass es dem vom Standardmodell vorausgesagten Higgs - Boson stark ahnelt .
# @@@@@@@@@@@@@
# Source: In addition , new data unveiled this week at a large physics Congress in Kyoto seem to confirm this , but there are still insufficient data to be perfectly sure .
# Generated: Daruber hinaus scheinen diese neuen Daten , die diese Woche auf einem großen Physikkongress in Kyoto bekannt gegeben wurden , dies zu bestatigen , aber es gibt noch immer unzureichende Daten , um sicher zu sein .
# Target: Daruber hinaus scheint dies durch neue Daten bestatigt zu werden , die in dieser Woche auf einem großen Physik - Kongress in Kyoto vorgestellt wurden , aber es fehlen noch Daten , um daruber vollkommen sicher zu sein .
# @@@@@@@@@@@@@
# Source: But let ' s suppose that it really is the Higgs , since the chances of being mistaken seem slim , and see what it is .
# Generated: Aber nehmen wir an , es ist wirklich die Higgs , da die Chancen , sich zu irren , schlank scheinen , und sehen , was es ist .
# Target: Gehen wir trotzdem davon aus , dass es sich tatsachlich um das Higgs handelt , da scheinbar nur ein geringes Risiko besteht , sich zu tauschen , und schauen wir uns an , um was es geht .
# @@@@@@@@@@@@@
# Source: In our world , there is a fatally unavoidable law which states that two things cannot meet at the same place at the same time .
# Generated: In unserer Welt gibt es ein todlich unvermeidliches Gesetz , das besagt , dass zwei Dinge nicht gleichzeitig zusammenkommen konnen .
# Target: Es gibt in dieser Welt ein zwangslaufig unumgangliches Gesetz , das bewirkt , dass zwei Objekte nicht gleichzeitig am selben Ort vorhanden sein konnen .
# @@@@@@@@@@@@@
# Source: There ' s no way to break this rule - and don ' t try too hard , you ' ll go mad .
# Generated: Es gibt keine Moglichkeit , diese Regel zu brechen - und versuchen Sie nicht zu hart , Sie werden verruckt .
# Target: Es ist nicht moglich , gegen diese Regel zu verstoßen - und versuchen Sie es nicht zu stark , da Sie sich wehtun werden .
# @@@@@@@@@@@@@
# Source: However , even though particle physics is a very strange world , it turns out that it also has a law of the same kind : the Pauli exclusion principle , which states that two particles cannot occupy the same space at the same time if they are in the same " quantum state " - this " state " consisting roughly of certain of their characteristics .
# Generated: Obwohl die Partikelphysik eine sehr seltsame Welt ist , stellt sich heraus , dass sie auch ein Gesetz derselben Art hat : das Pauli - Ausgrenzungsprinzip , das besagt , dass zwei Partikel nicht den gleichen Raum einnehmen konnen , wenn sie sich im selben " Quantenstaat " befinden - dieser " Staat " , der in etwa bestimmte ihrer Eigenschaften einbezieht .
# Target: Denn selbst wenn die Teilchenphysik eine wirklich seltsame Welt ist , stellt sich heraus , dass fur sie ebenfalls ein derartiges Gesetz gilt : das Pauli ' sche Ausschlussprinzip , das besagt , dass zwei Teilchen nicht den selben Raum zur selben Zeit besetzen konnen , wenn sie sich im selben " Quantenzustand " befinden , wobei dieser " Zustand " im Großen und Ganzen aus einigen ihrer Eigenschaften besteht .
# @@@@@@@@@@@@@
# Source: Based on this , physicists classify particles into two categories .
# Generated: Ausgehend davon klassifizieren Physiker Partikel in zwei Kategorien .
# Target: Davon ausgehend teilen die Physiker die Teilchen in zwei Kategorien ein .
# @@@@@@@@@@@@@
# Source: In one corner we have good citizens called fermions , who wisely obey the Pauli principle .
# Generated: In einer Ecke haben wir gute Burger namens Fermions , die weise dem Pauli - Prinzip folgen .
# Target: In einer Ecke befinden sich die guten Burger , die als Fermione bezeichnet werden und artig dem Pauli - Prinzip gehorchen .
# @@@@@@@@@@@@@
# Source: While lurking in the other are the bosons , a nasty band of anarchists who respect nothing - at all events , not this principle , which means that they can indeed be found in the same place at the same time .
# Generated: Wahrend im Anderen die Sohne lauern , eine schlimme Gruppe von Anarchisten , die nichts respektieren - auf jeden Fall nicht dieses Prinzip , was bedeutet , dass sie tatsachlich am gleichen Ort zur gleichen Zeit gefunden werden konnen .
# Target: Und in der anderen bewegen sich die Bosonen , eine uble Bande von Anarchisten , denen nichts heilig ist - auf jeden Fall nicht dieses Prinzip , was bedeutet , dass sie sich in der Tat zur selben Zeit am selben Ort befinden konnen .
# @@@@@@@@@@@@@
# Source: These bosons are then divided into two groups , according to the Berkeley Labs Particle Adventure site ( absolutely extraordinary , by the way ) : mesons , which we will not discuss here , and " force particles " by which the great forces of nature are propagated and to which the Higgs boson may be somehow related .
# Generated: Diese Bosonen sind dann in zwei Gruppen geteilt , nach der Berkeley Labs Particle Adventure - Site ( absolut außergewohnlich , ubrigens ) : Maschen , die wir hier nicht diskutieren , und " Kraft Partikel " , durch die die großen Krafte der Natur propagiert werden und denen die Higgs Boson irgendwie .
# Target: Diese Bosonen gliedern sich gemaß der Webseite The Particle Adventure von den Berkeley Laboren ( die ubrigens absolut erstaunlich ist ) in zwei Gruppen auf : die Mesonen , die wir hier nicht behandeln werden und die " Kraftteilchen " , durch die sich die großen Krafte der Natur verbreiten und mit denen das Higgs - Boson irgendwie verwandt ware .
# @@@@@@@@@@@@@
# Source: These bosons , it must be stressed here , are not all such exotic bugs as you might think .
# Generated: Diese Sohne , das muss hier betont werden , sind nicht alle solche exotischen Fehler , wie Sie vielleicht denken .
# Target: Es muss hier aber betont werden , dass diese Bosonen nicht alle derart exotische Kreaturen sind , wie man meinen konnte .
# @@@@@@@@@@@@@
# ...
# @@@@@@@@@@@@@
# Source: " I didn ' t realise this was going to be the most apocalyptic term ever " said Charme this week to students at Rutgers - Camden University ( New Jersey ) .
# Generated: " Ich wusste nicht , dass dies der apokalyptische Begriff aller Zeiten sein wird " , sagte Charme diese Woche an Studenten der Rutgers - Camden University ( New Jersey ) .
# Target: " Ich habe nicht gemerkt , dass dies das apokalyptischste Semester sein wird , das es jemals gab " sagte Charme diese Woche den Studenten an der Universitat Rutgers - Camden ( New Jersey ) .
# @@@@@@@@@@@@@
# Source: If you look at what has been happening in the world today as if we were at 30 days and counting , this has been a really good period .
# Generated: Wenn man sich ansieht , was heute in der Welt passiert ist , als ob wir 30 Tage waren und die Zahlen zahlen , dann war dies eine wirklich gute Zeit .
# Target: Wenn jemand analysiert , was heute in der Welt vorgefallen ist , als ob wir dreißig Tage davon entfernt waren , ware dies eine wirklich gute Periode .
# @@@@@@@@@@@@@
# Source: And remember that bad is good for those with an apocalyptic mentality .
# Generated: Und denken Sie daran , dass schlecht ist gut fur diejenigen mit einer apokalyptischen Mentalitat .
# Target: Und er erinnert daran , dass das Schlechte gut fur jene mit apokalyptischer Mentalitat ist .
# @@@@@@@@@@@@@
# Source: And he is not the only professor who offers courses on the " end of the world " this term , theoretically the last in history .
# Generated: Und er ist nicht der einzige Professor , der am " Ende der Welt " diesen Begriff anbietet , theoretisch der letzte in der Geschichte .
# Target: Und er ist nicht der einzige Professor , der dieses Semester , das eigentlich das letzte in der Geschichte sein sollte , Kurse uber das " Ende der Welt " anbietet .
# @@@@@@@@@@@@@
# Source: At Temple , Associate Professor Barry Vacker is giving the course " Media , Culture and the end of the world . "
# Generated: In Temple gibt Associate Professor Barry Vacker den Kurs " Medien , Kultur und das Ende der Welt " .
# Target: In Temple gibt der beisitzende Professor Barry Vacker den Kurs " Medien , Kultur und das Ende der Welt . "
# @@@@@@@@@@@@@
# Source: Each week , students explore apocalyptic themes such as nuclear war , zombies , viruses and germs , and global warming .
# Generated: Jede Woche erforschen Studenten apokalyptische Themen wie Atomkrieg , Zombies , Viren und Keime und globale Erwarmung .
# Target: Jede Woche untersuchen die Studenten apokalyptische Themen wie z . B . den Atomkrieg , Zombies , Virus und Keime und die globale Erwarmung .
# @@@@@@@@@@@@@
# Source: " We looked at why these ideas proliferate over time " he said , and how they offer hypothetical scenarios that guide human behaviour .
# Generated: " Wir haben untersucht , warum diese Ideen im Laufe der Zeit verbreitet " sagte er , und wie sie bieten hypothetische Szenarien , die menschliches Verhalten leiten .
# Target: " Wir analysieren , weshalb sich diese Ideen mit der Zeit ausbreiten " , sagte er , sowie die Art und Weise , wie hypothetische Szenarien angeboten werden , die zu einem bestimmten menschlichen Verhalten fuhren .
# @@@@@@@@@@@@@
# Source: If nuclear material falls into the hands of terrorists , for example , a war could break out .
# Generated: Wenn beispielsweise Nuklearmaterial in die Hande von Terroristen fallt , konnte ein Krieg ausbrechen .
# Target: Wenn nukleares Material in die Hande von Terroristen gelangt , konnte beispielsweise ein Krieg ausbrechen .
# @@@@@@@@@@@@@
# Source: This month students analysed movies with an apocalyptic theme and explored how they compare with real - life examples .
# Generated: In diesem Monat analysierten Studenten Filme mit einem apokalyptischen Thema und erforschten , wie sie mit realen Beispielen vergleichen .
# Target: Diesen Monat analysierten die Studenten Filme mit apokalyptischem Inhalt und untersuchten , wie sie sich im Vergleich mit dem wirklichen Leben vergleichen ließen .
# @@@@@@@@@@@@@
# Source: " I ' ve tried to inform students about what is possible , probable , credible and impossible " said Vacker .
# Generated: " Ich habe versucht , Studenten daruber zu informieren , was moglich , wahrscheinlich , glaubwurdig und unmoglich ist " , sagte Vacker .
# Target: " Ich habe versucht , die Studenten daruber zu informieren , was moglich , wahrscheinlich , glaubhaft und unmoglich ist " , sagte Vacker .
# @@@@@@@@@@@@@
# Source: At the main Pennsylvania State University campus , Latin American History Professor Matthew Restall , and his colleague Amara Solari , an Associate Art History and Anthropology Professor , have teamed up to give a course , called simply " The end of the world . "
# Generated: Auf dem Hauptcampus der Pennsylvania State University haben Professor Matthew Restall und seine Kollegin Amara Solari , Associate Art History und Anthropology Professor , sich zusammengetan , um einen Kurs zu halten , der einfach " Das Ende der Welt " genannt wird .
# Target: Auf dem Hauptcampus der Universitat Pennsylvania haben der Professor fur lateinamerikanische Geschichte Matthew Restall und seine Kollegin Amara Solari , eine beisitzende Professorin fur Kunstgeschichte und Anthropologie ein Team gebildet , um einen Kurs mit der schlichten Bezeichnung " Das Ende der Welt " anzubieten .
# @@@@@@@@@@@@@
# Source: " We don ' t add ' 2012 ' so we always have the option of running the course again , if the world doesn ' t come to an end " said Restall .
# Generated: " We don ' t add ' 2012 ' so we always have the option of running the course again , if the world doesn ' t come to end " , sagte Restall .
# Target: " Wir nehmen 2012 nicht auf , damit wir immer die Option behalten , den Kurs neu abhalten zu konnen , fur den Fall , dass die Welt nicht untergeht " , sagte Restall .
# @@@@@@@@@@@@@
# Source: Despite the " impending doom , " students have to study , undertake projects and take final exams .
# Generated: Trotz des drohenden Untergangs mussen Studenten studieren , Projekte durchfuhren und Abschlussprufungen durchfuhren .
# Target: Trotz des " bevorstehenden Untergangs " mussen die Studenten studieren , Projekte erstellen und an Abschlussprufungen teilnehmen .
# @@@@@@@@@@@@@
# Source: At Penn State , the final exam will be taken on the eve of the Apocalypse , which leaves students no choice but to work " until the very night the world is supposed to end " said Restall .
# Generated: In Penn State wird die Abschlussprufung am Vorabend der Apokalypse durchgefuhrt , die Studenten keine andere Wahl lasst als zu arbeiten " , sagte Restall .
# Target: In Penn State wird die Abschlussprufung am Vorabend der Apokalypse durchgefuhrt , weshalb die Studenten keine andere Chance haben , als " bis zur Nacht weiterzuarbeiten , wo die Welt angeblich zu Ende geht " , sagte Restall .
# @@@@@@@@@@@@@
# Source: The courses proved quite popular .
# Generated: Die Kurse waren sehr beliebt .
# Target: Die Kurse waren sehr beliebt .
# @@@@@@@@@@@@@
# Source: " It was fully booked within two hours " said Restall , on his course for students with high averages , which was filled with 35 students .
# Generated: " Es wurde vollstandig gebucht innerhalb von zwei Stunden " sagte Restall , auf seinem Kurs fur Studenten mit hohen Durchschnittswerten , die mit 35 Studenten gefullt war .
# Target: " In zwei Stunden gab es keine Platze mehr " sagte Restall uber seinen Kurs fur Studenten mit hohem Durchschnitt , der sich mit 35 Studenten fullte .
# @@@@@@@@@@@@@
# Source: We received emails for weeks and weeks before the start of the term , from people asking if there were any places .
# Generated: Wir haben Wochen und Wochen vor Beginn der Amtszeit E - Mails von Personen erhalten , die fragen , ob es irgendwelche Orte gibt .
# Target: Wochenlang vor Semesterbeginn erhielten wir E - Mails von Studenten , die fragten , ob noch Platze frei seien .
# @@@@@@@@@@@@@
# Source: Students , meanwhile , say the course is one of the most interesting around .
# Generated: Students , also , say the course is one of the most interesting around .
# Target: Die Studenten ihrerseits versichern , dass der Kurs zu den Interessantesten zahlt .
# @@@@@@@@@@@@@
# Source: " I find it fascinating to see what people do to console themselves " said Bridgid Robinson , a 23 - year - old post - graduate Religion and Sociology student from Haddonfield , New Jersey , at Rutgers - Camden .
# Generated: " Ich finde es faszinierend zu sehen , was Leute tun , um sich zu trosten " , sagte Bridgid Robinson , ein 23 - jahriger postgraduierter Religion und Soziologe aus Haddonfield , New Jersey , bei Rutgers - Camden .
# Target: " Es ist faszinierend zu sehen , was die Leute tun , um sich selbst zu trosten " , sagte Bridgid Robinson , eine 23 - jahrige Studentin in Rutgers - Camden fur Religion und Soziologie aus Haddonfield , New Jersey .
# @@@@@@@@@@@@@
# Source: And the apocalyptic , secular or religious mentality is just a matter consolation or a lack of it .
# Generated: Und die apokalyptische , sakulare oder religiose Mentalitat ist nur ein Trost oder ein Mangel daran .
# Target: Die apokalyptische Sekten - oder Religionsmentalitat ist eigentlich nur eine Frage von Trost oder dessen Fehlen .
# @@@@@@@@@@@@@
# Source: Will Wekesa , a 25 - year - old post - graduate Psychology and Nursing student , said he had seen all the apocalyptic movies .
# Generated: Will Wekesa , ein 25 - jahriger Postgraduierte Psychologie und Nursing Student , sagte , er habe alle apokalyptischen Filme gesehen .
# Target: Der 25 - jahrige Student Will Wekesa fur Psychologie und Krankenpflege erklart , alle apokalyptischen Filme gesehen zu haben .
# @@@@@@@@@@@@@
# Source: " I ' d never heard of a class that could teach it " he said .
# Generated: " Ich hatte nie gehort , eine Klasse , die es lehren konnte " sagte er .
# Target: " Nie habe ich etwas von einem Unterricht gehort , wo dies unterrichtet wird " , gab er an .
# @@@@@@@@@@@@@
# Source: I enjoy it .
# Generated: Ich genieße es .
# Target: Ich genieße es .
# @@@@@@@@@@@@@
# Source: But none of the students interviewed - much less any professor - said they believed in the end date of December 21st .
# Generated: Doch keiner der interviewten Studenten , geschweige denn Professorinnen und Professoren , sagte , sie glaubten am Ende des 21 . Dezember .
# Target: Aber keiner der befragten Studenten - und weniger noch ein Professor - erklarte , an das letzte Datum des 21 . Dezembers zu glauben .
# @@@@@@@@@@@@@
# Source: " Our first project was about the Mayan prophecy and to a certain extent we discredited it " said Julie Zeglen , a 21 - year - old final year student at Temple , from West Chester .
# Generated: " Unser erstes Projekt war uber die Maya - Prophezeiung und in gewissem Maße haben wir es diskreditiert " , sagte Julie Zeglen , ein 21 - jahriger Abschlussstudent in Temple , aus West Chester .
# Target: " Unser erstes Projekt behandelte die Prophezeiung der Mayas , und auf bestimmte Art und Weise diskreditieren wir sie " , sagte Julie Zeglen , Student im letzten Jahr in Temple , 21 Jahre alt und aus West Chester .
# @@@@@@@@@@@@@
# Source: The Mayans never predicted the end of the world : it is just a key point in the calendar , said Restall .
# Generated: Die Mayas haben nie das Ende der Welt vorhergesagt : Es ist nur ein Schlusselpunkt im Kalender , sagte Restall .
# Target: Die Mayas sagten nie das Ende der Welt voraus ; es handelt sich nur um einen Schlusselpunkt im Kalender , sagte Restall .
# @@@@@@@@@@@@@
# Source: But he said that Western culture suffers from apocalyptic anxiety , which goes back several centuries , in which people react to changes around them by predicting the end of the world .
# Generated: Aber er sagte , dass die westliche Kultur unter apokalyptischen Angsten leidet , die mehrere Jahrhunderte zuruckreichen , in denen die Menschen auf Veranderungen um sie herum reagieren , indem sie das Ende der Welt vorhersagen .
# Target: Er merkt allerdings an , dass in der westlichen Gesellschaft eine apokalyptische Angst besteht , die mehrere Jahrhunderte zuruckfuhrt , als die Leute auf Anderungen in ihrer Umgebung mit der Vorhersage des Endes der Welt reagierten .
# @@@@@@@@@@@@@
# Source: The Internet has caused a boom in these speculations .
# Generated: Das Internet hat zu einem Boom dieser Spekulationen gefuhrt .
# Target: Das Internet hat diese Spekulationen erhoht .
# @@@@@@@@@@@@@
# Source: " In other places , people don ' t think about it " he said .
# Generated: " An anderen Orten denkt man nicht daran " , sagte er .
# Target: " Anderenorts denken die Leute nicht so " , sagt er .
# @@@@@@@@@@@@@
# Source: It ' s mostly in the English - speaking world .
# Generated: Es ist vor allem in der englischsprachigen Welt .
# Target: Dies ist hauptsachlich in der englischsprechenden Welt der Fall .
# @@@@@@@@@@@@@
# Source: Joseph Dougherty , a Professor of religion at La Salle University , who is giving courses in the Philippines this year , responded quickly to the question of whether he knew about any courses on the " end of the world " there .
# Generated: Joseph Dougherty , Professor fur Religion an der Universitat La Salle , der in diesem Jahr Kurse auf den Philippinen anbietet , reagierte schnell auf die Frage , ob er uber irgendwelche Kurse am " Ende der Welt " dort wusste .
# Target: Joseph Dougherty , ein Religionsprofessor der Universitat La Salle , der dieses Jahr auf den Philippinen unterrichtet , antwortet schnell auf die Frage , ob er dort einen Kurs uber das " Ende der Welt " kennen wurde .
# @@@@@@@@@@@@@
# Source: " The Philippines are not taking part in the end of the world " he wrote , suggesting an exception of a higher authority .
# Generated: " Die Philippinen nehmen am Ende der Welt nicht teil " , schrieb er und schlug eine Ausnahme von einer hoheren Autoritat vor .
# Target: " Die Philippinen beteiligen sich nicht am Ende der Welt " , schrieb er als Andeutung auf eine Ausnahme einer hoheren Instanz .
# @@@@@@@@@@@@@
# Source: We have an indulgence from the Pope .
# Generated: Wir haben eine Nachsicht vom Papst .
# Target: Wir haben eine Begnadigung vom Papst .
# @@@@@@@@@@@@@
# Source: Restall noted that over the years there has been talk of many days of the last judgement , and said that if nothing happens on December 21st , " people will immediately start thinking of the next date " or philosophising that December 21st is the beginning of a seven - year period after which the world will end .
# Generated: Restall stellte fest , dass in den Jahren gab es viele Tage des letzten Urteils gesprochen , und sagte , dass , wenn nichts passiert am 21 . Dezember " , die Menschen sofort anfangen werden , an das nachste Datum zu denken " oder Philosophen , dass der 21 . Dezember ist der Beginn einer siebenjahrigen Periode , nach denen die Welt zu Ende .
# Target: Restall wies darauf hin , dass uber die Jahre viele Tage vom letzten Gericht gesprochen wurde , und sagte , dass wenn am 21 . Dezember nichts passiert , " die Leute sofort an ein neues Datum denken " oder daruber philosophierten , dass der 21 . Dezember der Beginn einer siebenjahrigen Periode sei , wonach das Ende der Welt kame .
# @@@@@@@@@@@@@
# Source: Students and teachers are taking the date lightly .
# Generated: Schuler und Lehrer nehmen das Datum leicht .
# Target: Studenten und Professoren nehmen dieses Datum leicht .
# @@@@@@@@@@@@@
# Source: Some said they plan to go to " end of the world " parties .
# Generated: Einige sagten , sie beabsichtigen , zu " Ende der Welt " Parteien .
# Target: Mehrere sagten , dass sie zu Feiern uber " das Ende der Welt " gehen mochten .
# @@@@@@@@@@@@@
# Source: " Maybe I ' ll call some friends so we can have a laugh together " said Samira Ford , 20 - year - old communications student .
# Generated: " Vielleicht werde ich einige Freunde nennen , damit wir gemeinsam lachen konnen " , sagte Samira Ford , 20 - jahrige Kommunikationsteilnehmer .
# Target: " Vielleicht rufe ich ein paar Freunde an , damit wir zusammen lachen konnen " , sagte Samira Ford , eine 20 - jahrige Studentin fur Kommunikationen .
# @@@@@@@@@@@@@

# %% [markdown]
# ## h1

# %%
import torch
from model import Transformer
import config 
from load_data import prepare_data
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, BatchSampler
import config
from load_data import prepare_data
from dataloader import TranslationDataset, collate_fn
from model import Transformer
from torch.optim.lr_scheduler import LambdaLR
import math
import torch.optim as optim
from utils import lr_lambda, load_checkpoint
import json
from tqdm import tqdm  # tqdm 라이브러리 임포트
import os

import traceback
import sys


# ckpt.pth 파일 경로
ckpt_path = "/home/user15/TT4/model/100000_checkpoint_h8.pth"

# 파일 불러오기
checkpoint = torch.load(ckpt_path, map_location=torch.device('cpu'))

# 내용 확인
for key in checkpoint.keys():
    print(f"{key}: {type(checkpoint[key])}")

model = Transformer(config.vocab_size, config.embedding_dimension,config.hidden_dimension,config.n_head,config.n_layers,config.h_ff, config.dropout_rate, config.device)
model.load_state_dict(checkpoint['model_state_dict'], strict=True)
model.to(config.device)

tokenizer = checkpoint['tokenizer']

# Data load
dev_pairs, tokenizer = prepare_data(config.path_ , tokenizer, 'test', config.max_sentence_len)
print("source data is loaded...")

print(len(dev_pairs[0]))


dev_dataset = TranslationDataset(dev_pairs,config.max_sentence_len)
dev_data_loader = DataLoader(dev_dataset, shuffle=True, batch_size=config.batch_size, collate_fn=collate_fn)
criterion = nn.CrossEntropyLoss() #, ignore_index = config.PAD)


model.eval()
dev_loss = 0.0

for train_batch in dev_data_loader:
    source_sentence, target_sentence, src_len, tgt_len = train_batch
    source_sentence = source_sentence.to(config.device)
    target_sentence = target_sentence.to(config.device)

    #tgt_sentence = target_sentence[target_sentence != 1].view(target_sentence.size(0), -1)
    
    predict = model(source_sentence, target_sentence[:, :-1])
    loss = criterion(predict.view(-1, predict.size(-1)), target_sentence[:, 1:].contiguous().view(-1))

    
    dev_loss += loss.item()

print(dev_loss/len(dev_data_loader))
# Out:
# /tmp/ipykernel_5199/433025303.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=torch.device('cpu'))
# step: <class 'int'>
# model_state_dict: <class 'collections.OrderedDict'>
# optimizer_state_dict: <class 'dict'>
# scheduler_state_dict: <class 'dict'>
# train_losses: <class 'list'>
# train_ppls: <class 'list'>
# tokenizer: <class 'tokenizers.Tokenizer'>
#
# Loading saved tokenizer...
# length of the pairs 2972
# source data is loaded...
# 2
# 1.5721621764309874

# %%
import torch
from model import Transformer
import config 
from load_data import prepare_data
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, BatchSampler
import config
from load_data import prepare_data
from dataloader import TranslationDataset, collate_fn
from model import Transformer
from torch.optim.lr_scheduler import LambdaLR
import math
import torch.optim as optim
from utils import lr_lambda, load_checkpoint
import json
from tqdm import tqdm  # tqdm 라이브러리 임포트
import os

import traceback
import sys

ckpt_paths = ["/home/user15/TT4/model/94000_checkpoint_h8.pth", \
            "/home/user15/TT4/model/95500_checkpoint_h8.pth", \
            "/home/user15/TT4/model/97000_checkpoint_h8.pth", \
            "/home/user15/TT4/model/98500_checkpoint_h8.pth", \
            "/home/user15/TT4/model/100000_checkpoint_h8.pth"]

checkpoints = [torch.load(ckpt, map_location="cpu") for ckpt in ckpt_paths]



# 첫 번째 체크포인트를 기반으로 평균 가중치를 저장할 새로운 dict 생성
avg_model_state_dict = {key: torch.zeros_like(value) for key, value in checkpoints[0]['model_state_dict'].items()}

# 모든 모델 가중치를 더하기
for checkpoint in checkpoints:
    for key in avg_model_state_dict.keys():
        avg_model_state_dict[key] += checkpoint['model_state_dict'][key]

# 평균 계산
for key in avg_model_state_dict.keys():
    avg_model_state_dict[key] /= len(checkpoints)

# 새로운 체크포인트 딕셔너리 생성 (기존 정보 유지)
new_checkpoint = {
    'step': checkpoints[0]['step'],  # 첫 번째 체크포인트의 step 값 사용
    'model_state_dict': avg_model_state_dict,  # 평균 가중치 적용
    'optimizer_state_dict': checkpoints[0]['optimizer_state_dict'],  # 첫 번째 옵티마이저 상태 유지
    'scheduler_state_dict': checkpoints[0]['scheduler_state_dict'],  # 첫 번째 스케줄러 상태 유지
    'train_losses': checkpoints[0]['train_losses'],  # 첫 번째 loss 정보 유지
    'train_ppls': checkpoints[0]['train_ppls'],  # 첫 번째 perplexity 정보 유지
    'tokenizer': checkpoints[0]['tokenizer'],  # 첫 번째 tokenizer 유지
}

model = Transformer(config.vocab_size, config.embedding_dimension,config.hidden_dimension,config.n_head,config.n_layers,config.h_ff, config.dropout_rate, config.device)
model.load_state_dict(new_checkpoint['model_state_dict'], strict=True)
model.to(config.device)

tokenizer = new_checkpoint['tokenizer']

# Data load
dev_pairs, tokenizer = prepare_data(config.path_ , tokenizer, 'dev', config.max_sentence_len)
print("source data is loaded...")

print(len(dev_pairs[0]))


dev_dataset = TranslationDataset(dev_pairs,config.max_sentence_len)
dev_data_loader = DataLoader(dev_dataset, shuffle=True, batch_size=config.batch_size, collate_fn=collate_fn)
criterion = nn.CrossEntropyLoss() #, ignore_index = config.PAD)


model.eval()
dev_loss = 0.0

for train_batch in dev_data_loader:
    source_sentence, target_sentence, src_len, tgt_len = train_batch
    source_sentence = source_sentence.to(config.device)
    target_sentence = target_sentence.to(config.device)

    #tgt_sentence = target_sentence[target_sentence != 1].view(target_sentence.size(0), -1)
    
    predict = model(source_sentence, target_sentence[:, :-1])
    loss = criterion(predict.view(-1, predict.size(-1)), target_sentence[:, 1:].contiguous().view(-1))

    
    dev_loss += loss.item()

print(dev_loss/len(dev_data_loader))
# Out:
# /tmp/ipykernel_5199/2544330649.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoints = [torch.load(ckpt, map_location="cpu") for ckpt in ckpt_paths]
# Loading saved tokenizer...
# length of the pairs 3001
# source data is loaded...
# 2
# 1.4590389668700676

# %%
len(dev_data_loader)
# Out:
# 1486

# %%
import numpy as np

np.exp(1.4590389668700676)
# Out:
# 4.301823346404599
